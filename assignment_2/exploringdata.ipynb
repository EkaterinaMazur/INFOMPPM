# %%
import pandas as pd

# %%
#read the pkl file
arts = pd.read_pickle('data/arts.pkl')
cbbc = pd.read_pickle('data/cbbc.pkl')
comedy = pd.read_pickle('data/comedy.pkl')
documentaries = pd.read_pickle('data/documentaries.pkl')
entertainment = pd.read_pickle('data/entertainment.pkl')
films = pd.read_pickle('data/films.pkl')
from_the_archives = pd.read_pickle('data/from-the-archives.pkl')
history = pd.read_pickle('data/history.pkl')
lifestyle = pd.read_pickle('data/lifestyle.pkl')
music = pd.read_pickle('data/music.pkl')
science_and_nature = pd.read_pickle('data/science-and-nature.pkl')
signed = pd.read_pickle('data/signed.pkl')
sports = pd.read_pickle('data/sports.pkl')

# %%
documentaries
# Out:
#            category                                              title  \
# 0     Documentaries  Fight for First: Excel Esports - Series 1: 1. ...
# 1     Documentaries                Lady Boss: The Jackie Collins Story
# 2     Documentaries          The Iraq War - 3. It's Hell, Mr President
# 3     Documentaries  The 80s - Music’s Greatest Decade? - Series 1:...
# 4     Documentaries       Sacred Rivers with Simon Reeve - 1. The Nile
# ...             ...                                                ...
# 2774  Documentaries     Life on Earth - 11. The Hunters and the Hunted
# 2775  Documentaries               Life and Birth - Series 1: Episode 4
# 2776  Documentaries    The Century of the Self - 1. Happiness Machines
# 2777  Documentaries    28 Up: Millennium Generation - 14 Up: Episode 1
# 2778  Documentaries            The Wild Gardener - Series 1: Episode 2
#
#                                                    tags  \
# 0     BBC, iPlayer, TV, Fight for First: Excel Espor...
# ...

# %%
documentaries.loc[documentaries['description'].str.contains("Britain", case=False)]
# Out:
#            category                                              title  \
# 57    Documentaries            The Rainhill Story: Stephenson's Rocket
# 214   Documentaries  Dark Land: Hunting the Killers - Series 1: 2. ...
# 226   Documentaries  Gold Rush: Our Race to Olympic Glory - Series ...
# 235   Documentaries           Our Lives - Series 5: The Long Walk Home
# 441   Documentaries  Can't Get You Out of My Head - Series 1: 5. Pa...
# 444   Documentaries  Inside Story - £830,000,000 - Nick Leeson and ...
# 462   Documentaries              AstraZeneca: A Vaccine for the World?
# 489   Documentaries  Coast - Series 8 Reversions: 4. The Secret Lif...
# 502   Documentaries             Our Lives - Series 5: Aberdeen Harbour
# 505   Documentaries  imagine... - Spring 2006: 4. A Picture of the ...
# 522   Documentaries  We Are England - Sporting Heroes: Mick Walks F...
# 690   Documentaries       Queer Britain - Series 1: 6. Queer and Proud
# ...

# %%
from_the_archives.shape
# Out:
# (892, 11)

# %%
from_the_archives.head()
# Out:
#   category                                              title  \
# 0     Food       Celebrity MasterChef - Series 11: Episode 11
# 1     Food      Inside the Factory - Series 6: Tortilla Chips
# 2     Food  Marcus Wareing's Tales from a Kitchen Garden  ...
# 3     Food        Madhur Jaffrey's Flavours of India - Kerala
# 4     Food  MasterChef: The Professionals - Series 12: Epi...
#
#                                                 tags  \
# 0  BBC, iPlayer, TV, Celebrity MasterChef, Series...
# 1  BBC, iPlayer, TV, Inside the Factory, Series 6...
# 2  BBC, iPlayer, TV, Marcus Wareings Tales from a...
# 3  BBC, iPlayer, TV, Madhur Jaffreys Flavours of ...
# 4  BBC, iPlayer, TV, MasterChef: The Professional...
#
#                                          description  \
# 0  In Finals Week, the four remaining celebrities...
# 1  Gregg Wallace visits the biggest tortilla fact...
# 2  Marcus finds that getting his own ducks proves...
# ...

# %%
from_the_archives.groupby('category').count()
# Out:
#           title  tags  description  image  duration_txt  duration_sec  \
# category
# Food        892   892          892    892           892           892
#
#           first_broadcast  synopsis_small  synopsis_medium  synopsis_large
# category
# Food                  892             892              892             892

# %%
cbbc.head()
# Out:
#   category                                              title  \
# 0     CBBC  Holly Hobbie - Series 2: 8. The Dauntless Daug...
# 1     CBBC               Mystic - Series 2: 8. The New Future
# 2     CBBC           M.I. High - Series 7: 13. The Last Stand
# 3     CBBC                      The Zoo - Series 2: 7. Dr Zoo
# 4     CBBC  Horrible Histories - Series 7: 3. Ridiculous R...
#
#                                                 tags  \
# 0  BBC, iPlayer, TV, Holly Hobbie, Series 2: 8. T...
# 1  BBC, iPlayer, TV, Mystic, Series 2: 8. The New...
# 2  BBC, iPlayer, TV, M.I. High, Series 7: 13. The...
# 3     BBC, iPlayer, TV, The Zoo, Series 2: 7. Dr Zoo
# 4  BBC, iPlayer, TV, Horrible Histories, Series 7...
#
#                                          description  \
# 0  After Holly discovers a double standard, she j...
# 1  In the aftermath of the earthquake, the KP gan...
# 2  The spies only option is to take the war to Ko...
# ...

# %%
films.head()
# Out:
#   category                             title  \
# 0    Films               Lilies of the Field
# 1    Films                      Paddington 2
# 2    Films                            Tycoon
# 3    Films        The Young Offenders (film)
# 4    Films  The Gangster, the Cop, the Devil
#
#                                                 tags  \
# 0              BBC, iPlayer, TV, Lilies of the Field
# 1                     BBC, iPlayer, TV, Paddington 2
# 2                           BBC, iPlayer, TV, Tycoon
# 3       BBC, iPlayer, TV, The Young Offenders (film)
# 4  BBC, iPlayer, TV, The Gangster, the Cop, the D...
#
#                                          description  \
# 0  A travelling handyman has a profound effect on...
# 1  Paddington finds himself the prime suspect whe...
# 2  Romantic melodrama about an engineer battling ...
# 3  Pursued by police, two teenage boys on stolen ...
# 4  Jang realises there is a serial killer at larg...
#
# ...

# %%
arts_abc = pd.read_pickle('data/abc/arts.pkl')
arts_abc
# Out:
#     category                          title                         series  \
# 0     Comedy               Bangarra's World               Bangarra's World
# 1     Comedy          Mission Songs Project          Mission Songs Project
# 2     Comedy  The Story of Film: An Odyssey  The Story of Film: An Odyssey
# 3     Comedy                     Ballet Now                  No data found
# 4     Comedy   Julia Zemiro's Home Delivery   Julia Zemiro's Home Delivery
# ..       ...                            ...                            ...
# 907   Comedy               Recovery Reunion               Recovery Reunion
# 908   Comedy             Hannah Gadsby's OZ             Hannah Gadsby's OZ
# 909   Comedy                      Art Works                      Art Works
# 910   Comedy                        The Set                 The Set Extras
# 911   Comedy            Recovery: The Music            Recovery: The Music
#
#                                           episode_name  \
# ...

# %%
arts_abc.loc[arts_abc['description2'].str.contains("Australian", case=False)]
# Out:
#     category                          title                         series  \
# 13    Comedy              Classic Countdown              Classic Countdown
# 16    Comedy                        Compass                        Compass
# 17    Comedy                         Rewind                         Rewind
# 41    Comedy                  And We Danced                  And We Danced
# 57    Comedy                         Rewind                         Rewind
# ..       ...                            ...                            ...
# 850   Comedy                         Rewind                         Rewind
# 857   Comedy                   One Plus One                   One Plus One
# 871   Comedy          The Art of Collecting                  No data found
# 876   Comedy  The Story of Film: An Odyssey  The Story of Film: An Odyssey
# 908   Comedy             Hannah Gadsby's OZ             Hannah Gadsby's OZ
#
#                                           episode_name  \
# ...
